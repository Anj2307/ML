# %% [markdown]
# <a href="https://colab.research.google.com/github/Anj2307/ML/blob/main/muliple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#       X1      X2     X3       Y
# 0  37.45   87.36  63.80  415.28
# 1  95.07   83.29  31.07  660.93
# 2  73.20   67.62  40.80  492.74
# 3  59.87  110.73  59.80  620.95
# 4  15.60   97.66  48.93  433.84

# %%
plt.scatter(df['X1'],df['Y'])
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter Plot of X1 vs Y')
plt.show()

# %%
plt.scatter(df['X2'],df['Y'])
plt.xlabel('X2')
plt.ylabel('Y')
plt.title('Scatter Plot of X2 vs Y')
plt.show()

# %%
plt.scatter(df['X3'],df['Y'])
plt.xlabel('X3')
plt.ylabel('Y')
plt.title('Scatter Plot of X3 vs Y')
plt.show()

# %%
X=df[['X1','X2','X3']]
X
Y=df['Y']
Y
# Out:
# 0       415.28
# 1       660.93
# 2       492.74
# 3       620.95
# 4       433.84
#          ...
# 9995    772.54
# 9996    408.35
# 9997    630.76
# 9998    494.72
# 9999    347.41
# Name: Y, Length: 10000, dtype: float64

# %%
#train test split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#          X1      X2     X3
# 9254  77.08   64.69  76.96
# 1561  23.69   75.37  30.51
# 1670  38.06   83.67  48.63
# 6087  20.60  137.10  68.29
# 6669  13.03   84.85  27.70
# ...     ...     ...    ...
# 5734  67.71  100.63  35.45
# 5191  70.08   57.34  78.58
# 5390  13.95   64.96  31.73
# 860   77.55  144.95  36.69
# 7270  32.07   99.24  32.86
#
# [8000 rows x 3 columns]

# %%
#training the model
#standization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
#let's start train the model
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.coef_
model.intercept_
# Out:
# np.float64(549.45643625)

# %%
y_pred=model.predict(X_test)

# %%
#performance
from sklearn.metrics import r2_score

r2 = r2_score(Y_test, y_pred)
print(f"R² Score: {r2:.3f}")
# Out:
# R² Score: 0.997

# %%
# random prediction
print (model.predict ((([[2.54,74.12,76.83]]))))
# Out:
# [8873.04130505]

# %%
model_score=model.score(X_test,Y_test)
print(model_score)
model.coef_
# Out:
# 0.9965095704291469
# array([ 86.38870832, 145.12453796, -34.5239256 ])

# %% [markdown]
# values of slope and intercept is above making a line m1x1+m2x2+m3x3+b
