# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %% [markdown]
# 1. Catagorical Data

# %% [markdown]
# a. counterplot

# %%
sns.countplot(x=df['Survived'])
#
df['Survived'].value_counts().plot(kind="bar")
#plt.show()
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x=df["Sex"])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# b.piechart

# %%
df["Survived"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 2. Numerical Data

# %% [markdown]
# a. Histogram

# %%
plt.hist(df["Age"],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# b. Distplot

# %%
sns.displot(x=df["Age"])
#probability distribuation according the favourable age group

# %% [markdown]
# c.Boxplot
#     Boxplot plot is used to display the distribution of data. It is a graphical representation of the distribution of data based on a fiv

# %% [markdown]
# it is used to detect outliners

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# Above Bubbles are outliners

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df["Age"].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
# skew are used to detect how the data column are symmatrical
